# %%
import numpy as np
from demoparser2 import DemoParser

# %%
parser = DemoParser("test.dem")
event_df = parser.parse_event("player_death", player=["X", "Y"], other=["total_rounds_played"])
ticks_df = parser.parse_ticks(["X", "Y"])

# %%
event_df
# Out:
#      assistedflash   assister_X  assister_Y assister_name   assister_steamid  \
# 0            False -1872.045288 -321.619385       Murdock  76561198234008400
# 1            False          NaN         NaN          None               None
# 2            False          NaN         NaN          None               None
# 3            False          NaN         NaN          None               None
# 4            False -2248.190430  -40.864319        飞飞飞飞飞总  76561199482826649
# ..             ...          ...         ...           ...                ...
# 160          False          NaN         NaN          None               None
# 161          False  -242.833801 -859.897156     Pinkvinus  76561198835783829
# 162          False          NaN         NaN          None               None
# 163          False          NaN         NaN          None               None
# 164          False          NaN         NaN          None               None
#
#       attacker_X   attacker_Y attacker_name   attacker_steamid  attackerblind  \
# 0            NaN          NaN          None               None          False
# 1   -2284.672363   485.839996          ...,  76561199514709619          False
# 2   -2045.462769  -483.447632       Murdock  76561198234008400          False
# 3   -2028.386475  -488.723755       Murdock  76561198234008400          False
# 4   -1318.524780   491.342926         Mar4e  76561199144668748          False
# ..           ...          ...           ...                ...            ...
# 160 -1039.494385  -490.683716          ...,  76561199514709619          False
# 161          NaN          NaN          None               None          False
# 162 -1154.802002  -690.888672         xysle  76561198879248376          False
# 163  -562.558777 -1373.486328         Kl1ck  76561198973175974          False
# 164 -1154.802002  -690.888672         xysle  76561198879248376          False
#
#      ...  total_rounds_played       user_X       user_Y          user_name  \
# 0    ...                    0 -2560.603027   431.579620              Kl1ck
# 1    ...                    0          NaN          NaN               None
# 2    ...                    0 -1518.346680   404.232483              xysle
# 3    ...                    0 -2309.400146  -535.245850       zitraks mode
# 4    ...                    0 -2556.523438   104.031441  За Лебігу Картопл
# ..   ...                  ...          ...          ...                ...
# 160  ...                   22  -242.833801  -859.897156          Pinkvinus
# 161  ...                   22 -1045.657471  -538.618835               ...,
# 162  ...                   22          NaN          NaN               None
# 163  ...                   23  -562.558777 -1373.486328              Kl1ck
# 164  ...                   23 -1154.802002  -690.888672              xysle
#
#           user_steamid         weapon     weapon_fauxitemid  weapon_itemid  \
# 0    76561198973175974   usp_silencer  17293822569102704701    29627720235
# 1                 None          glock  17293822569102704644              0
# 2    76561198879248376   usp_silencer  17293822569102704701              0
# 3    76561199267386924   usp_silencer  17293822569102704701              0
# 4    76561199084094765   usp_silencer  17293822569102704701              0
# ..                 ...            ...                   ...            ...
# 160  76561198835783829  m4a1_silencer  17293822569102704700              0
# 161  76561199514709619           ak47  17293822569102704647              0
# 162               None            awp  17293822569102704649              0
# 163  76561198973175974          world
# 164  76561198879248376          world
#
#      weapon_originalowner_xuid  wipe
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  0
# 4                                  0
# ..                         ...   ...
# 160                                0
# 161                                0
# 162                                0
# 163                                0
# 164                                0
#
# [165 rows x 33 columns]

# %%
ranks_df = parser.parse_ticks(["crosshair_code"])
ranks_df
# Out:
#                              crosshair_code    tick            steamid  \
# 0        CSGO-MhQ4q-zxGhe-axFhr-xf8PV-ssmHB       1  76561199482826649
# 1        CSGO-jDo4R-KC6wn-GvetT-KKkeT-f4pxA       1  76561198835783829
# 2        CSGO-4kDih-DkuTC-m94pJ-Nwvo3-ucYHK       1  76561199144668748
# 3        CSGO-p49YL-ZF22O-6zGGF-WXMLZ-HVGOP       1  76561199267386924
# 4        CSGO-ZA3pO-XR9pv-2vZ98-vBisR-6sWPA       1  76561198234008400
# ...                                     ...     ...                ...
# 1226185  CSGO-OORp6-VUvbA-6SPZB-5oGH6-nCyXD  122674  76561199084094765
# 1226186  CSGO-3BM2a-fpkYP-NAz28-aoSqM-udBAA  122674  76561198879248376
# 1226187  CSGO-Goixd-cNYLF-M9tbQ-qfbnD-pzwPB  122674  76561199796949000
# 1226188  CSGO-MhQ4q-zxGhe-axFhr-xf8PV-ssmHB  122674  76561199482826649
# 1226189  CSGO-yjjiP-GfbU4-NYPrB-yoXHR-fFu8O  122674  76561198973175974
#
#                       name
# 0                   飞飞飞飞飞总
# 1                Pinkvinus
# 2                    Mar4e
# 3             zitraks mode
# 4                  Murdock
# ...                    ...
# 1226185  За Лебігу Картопл
# 1226186              xysle
# 1226187            MadunaM
# 1226188             飞飞飞飞飞总
# 1226189              Kl1ck
#
# [1226190 rows x 4 columns]
